# %% [markdown]
# # Brain Tumor CNN – Experimentation Notebook
#
# Quick interactive playground to iterate on preprocessing, model architecture and evaluation.
#
# All heavy lifting lives in the `src/` package — this notebook just wires things together.

# %%
# %load_ext autoreload
# %autoreload 2
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))

from src.utils import config as cfg
from src.utils.gpu import configure_gpu
configure_gpu()

# %% [markdown]
# ## 1. Inspect the dataset

# %%
from src.preprocessing.preprocess import build_datasets
train_ds, val_ds, test_ds, classes = build_datasets()
print('Classes:', classes)

# %% [markdown]
# ## 2. Visualize a batch

# %%
import matplotlib.pyplot as plt
for images, labels in train_ds.take(1):
    fig, axes = plt.subplots(2, 4, figsize=(12, 6))
    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i].numpy())
        ax.set_title(classes[labels[i].numpy()])
        ax.axis('off')
    plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3. Build & summarize the model

# %%
from src.models.cnn import build_cnn
model = build_cnn(); model.summary()

# %% [markdown]
# ## 4. Quick training (small epoch count for a sanity check)

# %%
from src.training.train import train
model = train(epochs=3)

# %% [markdown]
# ## 5. Evaluate

# %%
from src.evaluation.evaluate import evaluate
evaluate()
